# %% [markdown]
# <a href="https://colab.research.google.com/github/Lap9890/col3/blob/main/untitleeeeeeeeeed5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("test")
print("OK")
# Out:
# test
